# %% [markdown]
# <h1 style="background-color:white; color:#5D5C61; font-size:300%;"><u>Decision Tree Classification</u></h1>
# <ul>
#     <li style="font-size:150%;"> <i>Iris Dataset</i> </li>
# </ul>

# %% [markdown]
# ## <u style="font-size:150%;"> About the Dataset </u> ##
# <h2 <ul><p> <li style="font-size:100%; color:olive"> <i>This data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray </i></li> </p>
#
# <p><li style="font-size:100%; color:olive" > <i>The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width</i> </li> </p> </ul> </h2>

# %% [markdown]
# <img src="Iris header.png" />

# %% [markdown]
# ## Importing the dataset and other libraries ##

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from adspy_shared_utilities import plot_decision_tree
from sklearn.model_selection import train_test_split


iris = load_iris()

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state = 3)
clf = DecisionTreeClassifier().fit(X_train, y_train)

# %%
plot_decision_tree(clf, iris.feature_names, iris.target_names)
